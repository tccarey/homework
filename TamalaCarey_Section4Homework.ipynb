# %% [markdown]
# # Python Homework (Flow Control, Modules, Functions, Exceptions, NumPy)
#
# **Note**: You can create a Python file or a Jupyter Notebook file
#
# <br>
#
# **<ins>Use markdown formatting for the following questions (e.g., bold lettering, bullet points, different font sizes, etc.)</ins>**:
#
# 1. What does one need to do to use a module?
# - to use a module one needs to import it first and maybe find documentation telling you what's in its library.
#
# 2. Name a Module (not the DateTime Nodule) we looked at and write a line or 2 of code as an example using this module.
# - we looked at the math module.
# - import math
#     print(math.fabs(-503.99999))
#
# 3. What is a benefit of using Exception handling?
# - it is good to use to test code blocks for errors and has a subuset of statements to help catch/test the error.
#
# 4. what are the 4 components used for Python Exception Handling?
# - try
# - except
# - else
# - finally
#
# 5. NumPy arrays are like what Python data type?
# - these are like python lists of lists (or lists stacked on top of each other).
#
# 6. What is one of the main benefits of using NumPy arrays.
# - it is a faster more convenient way to occupy less memory in python code.
#
# 7. What is one of the main requirements about the 'dtype' of NumPy arrays?
# - it specifies array's data type and size and category of that data type specified in the numpy array.
#
# 8. Of the 10 uses of NumPy, name 2.
# - statistical operations and linear algebra
#
# 9. Name one of the other libraries we'll use with NumPy?
# - pandas
#
# 10. What is the shape of NumPy arrays?
# - Shape of numpy arrays specifiies array shape by dimension, length, and rows.
#
# 11. What is a Tensor?
# - a tensor is an array with 3+ dimensions.
#
# 12. Name a reason why it's better using  NumPy for Data Analysis than using a Python List?
# - a python list is mutable and does not have a fixed size with makes it able to store various types of data, but it is slow. numpy utilizes only one element type making it faster and more convenient in an array.
#
# 13. When creating an "empty" array, where do the elements come from?
# - the array will use the last elements in the code's memory to fill itself in. it will not be truly empty.

# %% [markdown]
# #### Flow Control Methods:
#
# 1. Create an if statement: if 'age' is greater than or equal to 25, print "Renting a car is more affordable", however if 'age' is less than 25, print "Renting a car is very expensive."

# %%
age = 26

if age >= 25:
    print("Renting a car is more affordable.")
elif age < 25: 
    print("Renting a car is very expensive.")
# Out:
# Renting a car is more affordable.

# %% [markdown]
# 2. Create and chain an if-else  statement: if 'age' is greater than or equal to 25, print "Renting a car is more affordable." If 'age' is less than 25 but greater than or equal to 18, print "Renting a car is very expensive." Finally, if age is less than 18, print "You cannot legally rent a car."

# %%
age = 26

if age >= 25:
    print("Renting a car is more affordable.")
elif age >=18 and age <25:
    print("Renting a car is very expensive.")
elif age < 18: 
    print("You cannot legally rent a car.")
# Out:
# Renting a car is more affordable.

# %% [markdown]
# 3. Loop over the following string to (1) count all the characters in the string and (2) print out all the vowels -- "The quick brown fox jumps over the lazy dog"

# %%
#1

hmwk_string = "The quick brown fox jumps over the lazy dog"
count = 0
for char in hmwk_string:
    count += 1
else:
    print(count)

#2

vowels = "aeiouAEIOU"
for char in hmwk_string:
    if char in vowels:
        print(char, end='')
# Out:
# 43
# euioouoeeao

# %% [markdown]
# 4. Write a nested loop that prints out every piece of clothing from the `couture` list, in every fashionable color from the `panettone` set: couture = ["trousers", "blouse", "bandana", "cumber band", "blazer", "vest", "french beret", "scarf", "stole"] and panettone = {"cerise", "fuchsia", "aqua", "maple", "auburn", "burnt sienna", "gunmetal blue", "Dark Sapphire"}

# %%
couture = ["trousers", "blouse", "bandana", "cumber band", "blazer", "vest", "french beret", "scarf", "stole"]
panettone = {"cerise", "fuchsia", "aqua", "maple", "auburn", "burnt sienna", "gunmetal blue", "Dark Sapphire"}

for x in panettone:
	for y in couture:
		print(x,y)
# Out:
# auburn trousers
# auburn blouse
# auburn bandana
# auburn cumber band
# auburn blazer
# auburn vest
# auburn french beret
# auburn scarf
# auburn stole
# gunmetal blue trousers
# gunmetal blue blouse
# gunmetal blue bandana
# gunmetal blue cumber band
# gunmetal blue blazer
# gunmetal blue vest
# gunmetal blue french beret
# gunmetal blue scarf
# gunmetal blue stole
# fuchsia trousers
# fuchsia blouse
# fuchsia bandana
# fuchsia cumber band
# fuchsia blazer
# fuchsia vest
# fuchsia french beret
# fuchsia scarf
# fuchsia stole
# cerise trousers
# cerise blouse
# cerise bandana
# cerise cumber band
# cerise blazer
# cerise vest
# cerise french beret
# cerise scarf
# cerise stole
# aqua trousers
# aqua blouse
# aqua bandana
# aqua cumber band
# aqua blazer
# aqua vest
# aqua french beret
# aqua scarf
# aqua stole
# maple trousers
# maple blouse
# maple bandana
# maple cumber band
# maple blazer
# maple vest
# maple french beret
# maple scarf
# maple stole
# burnt sienna trousers
# burnt sienna blouse
# burnt sienna bandana
# burnt sienna cumber band
# burnt sienna blazer
# burnt sienna vest
# burnt sienna french beret
# burnt sienna scarf
# burnt sienna stole
# Dark Sapphire trousers
# Dark Sapphire blouse
# Dark Sapphire bandana
# Dark Sapphire cumber band
# Dark Sapphire blazer
# Dark Sapphire vest
# Dark Sapphire french beret
# Dark Sapphire scarf
# Dark Sapphire stole

# %% [markdown]
# 5. Use range as a loop to calculate the sum of all the numbers from 1 to 100

# %%
total = 0

for num in range(1, 101):
    total += num

print(total)
# Out:
# 5050

# %% [markdown]
# 6. Print the second item in this fruits list.
#     ["apple", "banana", "cherry"]

# %%
fruits = ["apple", "banana", "cherry"]
print(fruits[1])
# Out:
# banana

# %% [markdown]
# 7. Change the value from "apple" to "kiwi", in the fruits list.
#     ["apple", "banana", "cherry"]

# %%
fruits = ["apple", "banana", "cherry"]
fruits[0] = "kiwi"
print(fruits)
# Out:
# ['kiwi', 'banana', 'cherry']

# %% [markdown]
# 8. Use the append method to add "orange" to the fruits list.
#     ["apple", "banana", "cherry"]

# %%
fruits = ["apple", "banana", "cherry"]
fruits.append("orange")
print(fruits)
# Out:
# ['apple', 'banana', 'cherry', 'orange']

# %% [markdown]
# 9. Use the insert method to add "lemon" as the second item in the fruits list.
#     ["apple", "banana", "cherry"]

# %%
fruits = ["apple", "banana", "cherry"]
fruits.insert(1, "lemon")
print(fruits)
# Out:
# ['apple', 'lemon', 'banana', 'cherry']

# %% [markdown]
# 10. Use the remove method to remove "banana" from the fruits list.
#     ["apple", "banana", "cherry"]

# %%
fruits = ["apple", "banana", "cherry"]
fruits.remove("banana")
print(fruits)
# Out:
# ['apple', 'cherry']

# %% [markdown]
# 11. Use negative indexing to print the 3rd and 2nd to last items in the list.
#     ["apple", "banana", "cherry", "orange", "kiwi", "melon", "mango"]

# %%
fruits_list =  ["apple", "banana", "cherry", "orange", "kiwi", "melon", "mango"]
print(fruits_list[-3:-1])
# Out:
# ['kiwi', 'melon']

# %% [markdown]
# 12. Use a range of indexes to print the third, fourth, and fifth item in the list.
#     ["apple", "banana", "cherry", "orange", "kiwi", "melon", "mango"]

# %%
fruits = ["apple", "banana", "cherry", "orange", "kiwi", "melon", "mango"]
print(fruits[2:5])
# Out:
# ['cherry', 'orange', 'kiwi']

# %% [markdown]
# 13. Use the correct syntax to print the number of items in the list.
#     ["apple", "banana", "cherry", "orange", "kiwi", "melon", "mango"]

# %%
fruits = ["apple", "banana", "cherry", "orange", "kiwi", "melon", "mango"]
print(len(fruits))
# Out:
# 7

# %% [markdown]
# #14. Use the correct syntax to sort this list in reverse order fruits = ["apple", "banana", "cherry", "orange", "kiwi", "melon", "mango"]

# %%
fruits = ["apple", "banana", "cherry", "orange", "kiwi", "melon", "mango"]
fruits.sort(reverse=True)
print(fruits)
# Out:
# ['orange', 'melon', 'mango', 'kiwi', 'cherry', 'banana', 'apple']

# %% [markdown]
# 15. Use the DateTime module to get Current Date and Time, and save it to a variable. Then extract just the Full month name form that variable.

# %%
import datetime as dt 
t = dt.datetime.now()
print(t)

print("current month: ", t.strftime("%B"))
# Out:
# 2026-09-24 20:23:50.318881
# current month:  September

# %% [markdown]
# 16. Write a simple function that takes 2 parameters -- a  first name and a day name.
#     - Set a default value for the day name of Sunday.
#     - Have the function print out a greeting -- using the parameters -- that says something like "Hi first-name! Happy day-name!". Remember to use the variables in the greeting to replace first-name and day-name.
#     - Invoke this function with 2 variables.
#     - Invoke this function with 1 variable only.

# %%
def greeting(fname, day = 'Sunday'):
    print("Hi " + fname + "! " + "Happy " + day  + "!")

greeting('tamala')

greeting('tamala', 'thursday')
# Out:
# Hi tamala! Happy Sunday!
# Hi tamala! Happy thursday!

# %% [markdown]
# 17. Write a block of code to handle one of the most common Python exception errors. Select one of the common errors from the curriculum section on Python Exception handling. Have your code example uses the `try`,`except`, `else`, and `finally` components.

# %%
my_list = ["Python","Java","C++","JavaScript"]
try:
    print(my_list[5])
except:
    print('something is wrong.')
finally:
    print('this example is complete.')

#the error is an index error since the index does not exist in list
# Out:
# something is wrong.
# this example is complete.

# %% [markdown]
# <br>
#
# #### When done with homework:
# - **Due Date**: The following Monday before class
# - Make sure your homework file is well named
# - Add the homework to your Homework repo
# - Use  `git add .`, `git commit -m "message"`, and `git push` to upload your homework changes to GitHub in the cloud
# - Create a JIRA ticket to indicate that your Homework is ready for review:
#     - <ins> In the "Summary" box</ins>: Include First Name and Last Initial, plus a short description in the Summary box (Ex: Jane D. Week # Homework Complete)
#     - <ins> In the "Description" box</ins>: Include GitHub repo url
#
# <br>
#
# ------------------------------------------------------------------------------------
